# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="-1"   
import MetaTrader5 as mt5
import time
from datetime import datetime, timedelta
from collections import deque
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
hour_offset = 8 # time - hour_offset = ny local time
mt5.initialize()
authorized=mt5.login(25031341, password = "!geH2e4Pi!Ka", server = "TickmillUK-Demo")
mt5.account_info()
dlen = 120
res_high = 100

# %%
class candle_class:
    def __init__(self, o=0,h=0,l=0,c=0,t=0):
        self.o=o
        self.h=h
        self.l=l
        self.c=c
        self.t=t
        
def get_prices(symbol, tf, lookback):
    t = int(time.time()) + 60*60*24

    prices = mt5.copy_rates_from(symbol, tf, t, lookback)
    
    candles = []
    for t,o,h,l,c,_,_,_ in prices:
        t = datetime.fromtimestamp(int(t)) - timedelta (hours=hour_offset)
        t = str(t.hour)+":"+str(t.minute)
        x = candle_class()
        x.h=h
        x.l=l
        x.o=o
        x.c=c
        x.t=t
        candles.append(x)
    
    
    return candles

# %%
candles = get_prices("EURUSD", mt5.TIMEFRAME_M15, 80000)

# %%
class timeframe_manager:
    def __init__(self, candles):
        self.candles = candles
        self.current_index = 0
            
        self.d1_candles = deque(maxlen = dlen)
        self.h4_candles = deque(maxlen = dlen)
        self.h1_candles = deque(maxlen = dlen)
        self.m15_candles = deque(maxlen = dlen)
    
    def get_next_sample_candles(self):
        if len(self.candles) == self.current_index:
            return -1, -1, -1, -1
        while True:
            # return dlen candles of d1, h4, h1 and m15
            current_candle = self.candles[self.current_index]
            current_hour = int(current_candle.t.split(":")[0])
            current_closing_minute = int(current_candle.t.split(":")[1])

            # m15 candles:
            open_minute = int(current_closing_minute / 15) * 15 # candle saved the last minute but opening minute is better to use
            self.m15_candles.append(candle_class(current_candle.o, current_candle.h, current_candle.l, current_candle.c, str(current_hour) +":"+str(open_minute)))

            # h1 candles:
            if  open_minute == 0: # a new hour candle started
                new_candle = candle_class(current_candle.o, current_candle.h, current_candle.l, current_candle.c, str(current_hour)+":00")
                self.h1_candles.append(new_candle)
            else:
                if len(self.h1_candles) > 0:
                    self.h1_candles[-1].c = current_candle.c
                    self.h1_candles[-1].h = max(current_candle.h, self.h1_candles[-1].h)
                    self.h1_candles[-1].l = min(current_candle.l, self.h1_candles[-1].l)

            # h4 candles:
            # create a new h4 candle when hour is 17, 21, 1, 5, 9, 13
            if  (current_hour == 17 or current_hour == 21 or current_hour == 1 or current_hour == 5 or current_hour == 9 or current_hour == 13) and open_minute == 0:
                new_candle = candle_class(current_candle.o, current_candle.h, current_candle.l, current_candle.c, str(current_hour)+":00")
                self.h4_candles.append(new_candle)
            else:
                if len(self.h4_candles) > 0:
                    self.h4_candles[-1].c = current_candle.c
                    self.h4_candles[-1].h = max(current_candle.h, self.h4_candles[-1].h)
                    self.h4_candles[-1].l = min(current_candle.l, self.h4_candles[-1].l)

            # d1 candles:
            # create a new d1 candle when hour is 17
            if  current_hour == 17 and open_minute == 0:
                new_candle = candle_class(current_candle.o, current_candle.h, current_candle.l, current_candle.c, str(current_hour)+":00")
                self.d1_candles.append(new_candle)
            else:
                if len(self.d1_candles) > 0:
                    self.d1_candles[-1].c = current_candle.c
                    self.d1_candles[-1].h = max(current_candle.h, self.d1_candles[-1].h)
                    self.d1_candles[-1].l = min(current_candle.l, self.d1_candles[-1].l)

            self.current_index+=1    
            if len(self.d1_candles) == dlen:
                break

        return self.m15_candles,  self.h1_candles, self.h4_candles, self.d1_candles
    
    
    def to_model_input(self, candles):
        def scale_p(p):
            return int((p - max_l) / hlrange * (res_high))
        max_h = 0
        max_l = 1000000
        for i in candles:
            if i.h > max_h:
                max_h = i.h
            if i.l < max_l:
                max_l = i.l
        hlrange = max_h - max_l
        
        
        def scale_time(t):
            hour = int(t.split(":")[0])
            minute = int(t.split(":")[1])
            total = hour * 60 + minute
            max_t = 24*60
            scaled = total / max_t
            return scaled
            
        
        
        image = []
        for i in candles:
            clm = np.zeros(shape = (res_high+1))
            color = 1 if i.o<i.c else -1
            high_scaled = scale_p(i.h)
            low_scaled = scale_p(i.l)
            clm[low_scaled:high_scaled] = 0.5 * color
            open_scaled = scale_p(i.o)
            close_scaled = scale_p(i.c)
            if color == 1:
                clm[open_scaled:close_scaled+1] = color
            if color == -1:
                clm[close_scaled:open_scaled+1] = color
                
            c_time = scale_time(i.t)
            clm[-1] = c_time
            image.append(clm)
        
        current_close = candles[-1].c
        scaled_close = scale_p(current_close)
        clm = np.zeros(shape = (res_high+1))
        clm[scaled_close] = 1
        image.append(clm)
        
        return np.array(image).T

# %%
tm = timeframe_manager(candles)

# %%
m15,h1,h4,d1 = tm.get_next_sample_candles()

# %%
plt.imshow(tm.to_model_input(m15))

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.05, **kwargs):
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.rate = rate
        super(TransformerBlock, self).__init__(**kwargs)
        self.att = tf.keras.layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential(
            [tf.keras.layers.Dense(ff_dim, activation="relu"), tf.keras.layers.Dense(embed_dim),]
        )
        self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = tf.keras.layers.Dropout(rate)
        self.dropout2 = tf.keras.layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)
    
    def get_config(self):
        base_config = super(TransformerBlock, self).get_config()
        base_config['embed_dim'] = self.embed_dim
        base_config['num_heads'] = self.num_heads
        base_config['ff_dim'] = self.ff_dim
        base_config['rate'] = self.rate
        return base_config
    
    
    
class PositionEmbedding(tf.keras.layers.Layer):
    def __init__(self, maxlen, embed_dim, **kwargs):
        self.maxlen = maxlen
        self.embed_dim = embed_dim
        super(PositionEmbedding, self).__init__(**kwargs)
        self.pos_emb = tf.keras.layers.Embedding(input_dim=maxlen, output_dim=embed_dim)

    def call(self, x):
        maxlen = self.maxlen
        positions = tf.range(start=0, limit=maxlen, delta=1)
        positions = self.pos_emb(positions)
        return x + positions
    
    def get_config(self):
        base_config = super(PositionEmbedding, self).get_config()
        base_config['maxlen'] = self.maxlen
        base_config['embed_dim'] = self.embed_dim
        return base_config

# %%
tf.keras.backend.clear_session()

def proc_chart(x):
    #x1 = image
    #x2 = time
    x1 = x[::, :-1, :-1]
    x2 = x[::,-1,:-1]
    current_pos = x[::,::, -1]

    x1 = tf.keras.layers.Reshape((res_high, dlen, 1))(x1)
    
    x5 = tf.keras.layers.Conv2D(16, 3,activation="relu", padding="same")(x1)
    x1 = tf.keras.layers.Concatenate()([x1,x5])
    x5 = tf.keras.layers.Conv2D(16, 3,activation="relu", padding="same")(x1)
    x1 = tf.keras.layers.Concatenate()([x1,x5])
    x5 = tf.keras.layers.Conv2D(16, 3,activation="relu", padding="same")(x1)
    x1 = tf.keras.layers.Concatenate()([x1,x5])
    x1 = tf.keras.layers.LayerNormalization()(x1)

    
    x1 = tf.transpose(x1,perm=[0, 2, 1, 3])
    x1 = tf.keras.layers.Reshape((dlen, res_high*x1.shape[-1]))(x1)
    x2 = tf.keras.layers.Reshape((dlen, 1))(x2)
    x1 = tf.keras.layers.Concatenate()([x1,x2])
        
    x1 = tf.keras.layers.Dense(512)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(256)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(128)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(64)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.LayerNormalization()(x1)
    
    
    x1 = PositionEmbedding(dlen, x1.shape[-1])(x1)
    x1 = TransformerBlock(x1.shape[-1], 8, 256)(x1)
    x1 = TransformerBlock(x1.shape[-1], 8, 256)(x1)
    x1 = TransformerBlock(x1.shape[-1], 8, 256)(x1)

    x1 = tf.keras.layers.Dense(256)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(256)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(32)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(16)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.LayerNormalization()(x1)
    x1 = tf.keras.layers.Flatten()(x1)
    x1 = tf.keras.layers.Concatenate()([x1,current_pos])
    x1 = tf.keras.layers.Dense(1024)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(512)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.Dense(512)(x1)
    x1 = tf.keras.layers.LeakyReLU()(x1)
    x1 = tf.keras.layers.LayerNormalization()(x1)
    return x1
    
if True:
    input_m15 = tf.keras.layers.Input(shape = (res_high+1, dlen+1))
    input_h1 = tf.keras.layers.Input(shape = (res_high+1, dlen+1))
    input_h4 = tf.keras.layers.Input(shape = (res_high+1, dlen+1))
    input_d1 = tf.keras.layers.Input(shape = (res_high+1, dlen+1))
    
    x1 = proc_chart(input_m15)
    x2 = proc_chart(input_h1)
    x3 = proc_chart(input_h4)
    x4 = proc_chart(input_d1)
    
    input_net_position = tf.keras.layers.Input(shape = (1))


    x = tf.keras.layers.Concatenate()([x1,x2,x3,x4,input_net_position])
    
    x = tf.keras.layers.Dense(2048)(x)
    x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Dense(1024)(x)
    x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Dense(1024)(x)
    x = tf.keras.layers.LeakyReLU()(x)
    x = tf.keras.layers.Dense(1024)(x)
    x = tf.keras.layers.LeakyReLU()(x)
    
    outputs = tf.keras.layers.Dense(2, activation = "linear", use_bias=False, dtype="float32")(x)
    model = tf.keras.Model([input_m15,input_h1,input_h4, input_d1, input_net_position], outputs)
    
model.summary()


model.load_weights("dqn_trading_transformer_2.h5")
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 101, 121)]   0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 101, 121)]   0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 101, 121)]   0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 101, 121)]   0
# __________________________________________________________________________________________________
# tf.__operators__.getitem (Slici (None, 100, 120)     0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, 100, 120)     0           input_2[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 100, 120)     0           input_3[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_9 (Sli (None, 100, 120)     0           input_4[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 100, 120, 1)  0           tf.__operators__.getitem[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 100, 120, 1)  0           tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 100, 120, 1)  0           tf.__operators__.getitem_6[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 100, 120, 1)  0           tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 100, 120, 16) 160         reshape[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 100, 120, 16) 160         reshape_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 100, 120, 16) 160         reshape_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 100, 120, 16) 160         reshape_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 100, 120, 17) 0           reshape[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 100, 120, 17) 0           reshape_3[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 100, 120, 17) 0           reshape_6[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 100, 120, 17) 0           reshape_9[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 120, 16) 2464        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 100, 120, 16) 2464        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 100, 120, 16) 2464        concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 100, 120, 16) 2464        concatenate_15[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 100, 120, 33) 0           concatenate[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 100, 120, 33) 0           concatenate_5[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 100, 120, 33) 0           concatenate_10[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 100, 120, 33) 0           concatenate_15[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 100, 120, 16) 4768        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 100, 120, 16) 4768        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 100, 120, 16) 4768        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 100, 120, 16) 4768        concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 100, 120, 49) 0           concatenate_1[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 100, 120, 49) 0           concatenate_6[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 100, 120, 49) 0           concatenate_11[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 100, 120, 49) 0           concatenate_16[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 100, 120, 49) 98          concatenate_2[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 100, 120, 49) 98          concatenate_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 100, 120, 49) 98          concatenate_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 100, 120, 49) 98          concatenate_17[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose (TFOpLam (None, 120, 100, 49) 0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 120)          0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_1 (TFOpL (None, 120, 100, 49) 0           layer_normalization_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 120)          0           input_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_2 (TFOpL (None, 120, 100, 49) 0           layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 120)          0           input_3[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_3 (TFOpL (None, 120, 100, 49) 0           layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_10 (Sl (None, 120)          0           input_4[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 120, 4900)    0           tf.compat.v1.transpose[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 120, 1)       0           tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 120, 4900)    0           tf.compat.v1.transpose_1[0][0]
# __________________________________________________________________________________________________
# reshape_5 (Reshape)             (None, 120, 1)       0           tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 120, 4900)    0           tf.compat.v1.transpose_2[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 120, 1)       0           tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 120, 4900)    0           tf.compat.v1.transpose_3[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 120, 1)       0           tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 120, 4901)    0           reshape_1[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 120, 4901)    0           reshape_4[0][0]
#                                                                  reshape_5[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 120, 4901)    0           reshape_7[0][0]
#                                                                  reshape_8[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 120, 4901)    0           reshape_10[0][0]
#                                                                  reshape_11[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 120, 512)     2509824     concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 120, 512)     2509824     concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 120, 512)     2509824     concatenate_13[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 120, 512)     2509824     concatenate_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 120, 512)     0           dense[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 120, 512)     0           dense_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 120, 512)     0           dense_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 120, 512)     0           dense_51[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 120, 256)     131328      leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 120, 256)     131328      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# dense_35 (Dense)                (None, 120, 256)     131328      leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 120, 256)     131328      leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 120, 256)     0           dense_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 120, 256)     0           dense_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 120, 256)     0           dense_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 120, 256)     0           dense_52[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 120, 128)     32896       leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 120, 128)     32896       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# dense_36 (Dense)                (None, 120, 128)     32896       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 120, 128)     32896       leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 120, 128)     0           dense_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 120, 128)     0           dense_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 120, 128)     0           dense_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 120, 128)     0           dense_53[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 120, 64)      8256        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 120, 64)      8256        leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# dense_37 (Dense)                (None, 120, 64)      8256        leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 120, 64)      8256        leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 120, 64)      0           dense_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 120, 64)      0           dense_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 120, 64)      0           dense_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 120, 64)      0           dense_54[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 120, 64)      128         leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 120, 64)      128         leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 120, 64)      128         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 120, 64)      128         leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# position_embedding (PositionEmb (None, 120, 64)      7680        layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# position_embedding_1 (PositionE (None, 120, 64)      7680        layer_normalization_11[0][0]
# __________________________________________________________________________________________________
# position_embedding_2 (PositionE (None, 120, 64)      7680        layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# position_embedding_3 (PositionE (None, 120, 64)      7680        layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# transformer_block (TransformerB (None, 120, 64)      166016      position_embedding[0][0]
# __________________________________________________________________________________________________
# transformer_block_3 (Transforme (None, 120, 64)      166016      position_embedding_1[0][0]
# __________________________________________________________________________________________________
# transformer_block_6 (Transforme (None, 120, 64)      166016      position_embedding_2[0][0]
# __________________________________________________________________________________________________
# transformer_block_9 (Transforme (None, 120, 64)      166016      position_embedding_3[0][0]
# __________________________________________________________________________________________________
# transformer_block_1 (Transforme (None, 120, 64)      166016      transformer_block[0][0]
# __________________________________________________________________________________________________
# transformer_block_4 (Transforme (None, 120, 64)      166016      transformer_block_3[0][0]
# __________________________________________________________________________________________________
# transformer_block_7 (Transforme (None, 120, 64)      166016      transformer_block_6[0][0]
# __________________________________________________________________________________________________
# transformer_block_10 (Transform (None, 120, 64)      166016      transformer_block_9[0][0]
# __________________________________________________________________________________________________
# transformer_block_2 (Transforme (None, 120, 64)      166016      transformer_block_1[0][0]
# __________________________________________________________________________________________________
# transformer_block_5 (Transforme (None, 120, 64)      166016      transformer_block_4[0][0]
# __________________________________________________________________________________________________
# transformer_block_8 (Transforme (None, 120, 64)      166016      transformer_block_7[0][0]
# __________________________________________________________________________________________________
# transformer_block_11 (Transform (None, 120, 64)      166016      transformer_block_10[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 120, 256)     16640       transformer_block_2[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 120, 256)     16640       transformer_block_5[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 120, 256)     16640       transformer_block_8[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 120, 256)     16640       transformer_block_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 120, 256)     0           dense_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 120, 256)     0           dense_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 120, 256)     0           dense_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 120, 256)     0           dense_61[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 120, 256)     65792       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 120, 256)     65792       leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 120, 256)     65792       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 120, 256)     65792       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 120, 256)     0           dense_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 120, 256)     0           dense_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 120, 256)     0           dense_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 120, 256)     0           dense_62[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 120, 32)      8224        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 120, 32)      8224        leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 120, 32)      8224        leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 120, 32)      8224        leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 120, 32)      0           dense_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 120, 32)      0           dense_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 120, 32)      0           dense_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 120, 32)      0           dense_63[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 120, 16)      528         leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 120, 16)      528         leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 120, 16)      528         leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 120, 16)      528         leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 120, 16)      0           dense_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 120, 16)      0           dense_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 120, 16)      0           dense_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 120, 16)      0           dense_64[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 120, 16)      32          leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 120, 16)      32          leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 120, 16)      32          leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_38 (LayerNo (None, 120, 16)      32          leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1920)         0           layer_normalization_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli (None, 101)          0           input_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1920)         0           layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 101)          0           input_2[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1920)         0           layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_8 (Sli (None, 101)          0           input_3[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1920)         0           layer_normalization_38[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_11 (Sl (None, 101)          0           input_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 2021)         0           flatten[0][0]
#                                                                  tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 2021)         0           flatten_1[0][0]
#                                                                  tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 2021)         0           flatten_2[0][0]
#                                                                  tf.__operators__.getitem_8[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 2021)         0           flatten_3[0][0]
#                                                                  tf.__operators__.getitem_11[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1024)         2070528     concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1024)         2070528     concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 1024)         2070528     concatenate_14[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 1024)         2070528     concatenate_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 1024)         0           dense_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 1024)         0           dense_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 1024)         0           dense_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 1024)         0           dense_65[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 512)          524800      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 512)          524800      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 512)          524800      leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 512)          524800      leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 512)          0           dense_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 512)          0           dense_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 512)          0           dense_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 512)          0           dense_66[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 512)          262656      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 512)          262656      leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 512)          262656      leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 512)          262656      leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 512)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 512)          0           dense_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 512)          0           dense_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 512)          0           dense_67[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 512)          1024        leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 512)          1024        leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 512)          1024        leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# layer_normalization_39 (LayerNo (None, 512)          1024        leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 2049)         0           layer_normalization_9[0][0]
#                                                                  layer_normalization_19[0][0]
#                                                                  layer_normalization_29[0][0]
#                                                                  layer_normalization_39[0][0]
#                                                                  input_5[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 2048)         4198400     concatenate_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 2048)         0           dense_68[0][0]
# __________________________________________________________________________________________________
# dense_69 (Dense)                (None, 1024)         2098176     leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 1024)         0           dense_69[0][0]
# __________________________________________________________________________________________________
# dense_70 (Dense)                (None, 1024)         1049600     leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 1024)         0           dense_70[0][0]
# __________________________________________________________________________________________________
# dense_71 (Dense)                (None, 1024)         1049600     leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 1024)         0           dense_71[0][0]
# __________________________________________________________________________________________________
# dense_72 (Dense)                (None, 2)            2048        leaky_re_lu_47[0][0]
# ==================================================================================================
# Total params: 32,981,320
# Trainable params: 32,981,320
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
entry_candles = deque(maxlen = dlen)
def plot_candles(candles, name, plot_entrys = False, was_entry = 0):
    global entry_candles
    if plot_entrys:
        if was_entry != 0:
            entry_candles.append([0,was_entry])
            
    
    def scale_p(p):
        return (p - max_l) / hlrange * h
    
    w = 300
    h = 200
    canvas = np.zeros((h,w,3), np.uint8) 
    l = dlen
    single_candle_w = w / l * 0.95
    max_h = 0
    max_l = 1000000
    for i in candles:
        if i.h > max_h:
            max_h = i.h
        if i.l < max_l:
            max_l = i.l
    hlrange = max_h - max_l
    
    for i in range(len(candles)):  
        color = (0,200,0) if candles[i].c > candles[i].o else (0,0,200)
        if plot_entrys:
            color = (0,100,0) if candles[i].c > candles[i].o else (0,0,100)
        cv2.rectangle(canvas, (int(i*single_candle_w),int(scale_p(candles[i].o))), (int((i+1)*single_candle_w),int(scale_p(candles[i].c))), color, -1)
        cv2.line(canvas, (int((i+0.5)*single_candle_w),int(scale_p(candles[i].h))), (int((i+0.5)*single_candle_w),int(scale_p(candles[i].l))), color)

    if plot_entrys:
        for i in range(len(entry_candles)):
            entry_candles[i][0]+=1
            
        if len(entry_candles) > 1 and len(candles) == dlen:
            for i in range(len(entry_candles)-1):
                entry = entry_candles[i][0]
                exit = entry_candles[i+1][0]
                position = entry_candles[i][1]
                if position == 2:continue
                startpos = dlen - entry
                endpos = dlen - exit
                if startpos > 0:
                    color = (0,255,0) if position == 1 else (0,0,255)
                    #print(startpos, endpos)
                    cv2.line(canvas, (int((startpos+0.5)*single_candle_w),int(scale_p(candles[startpos].c))), (int((endpos+0.5)*single_candle_w),int(scale_p(candles[endpos].c))), color, 2)
            
        
        
    canvas = canvas[::-1]
    
    cv2.imshow(name, canvas)
    cv2.waitKey(1)

    
def plot_outputs(outputs):
    
    def scale_p(p):
        return (p - max_l) / hlrange * h
    
    w = 300
    h = 200
    canvas = np.zeros((h,w,3), np.uint8) 
    l = dlen
    single_candle_w = w / l * 0.95
    max_h = 0
    max_l = 1000000
    for i in outputs:
        if max(i) > max_h:
            max_h = max(i)
        if min(i) < max_l:
            max_l = min(i)
    hlrange = max_h - max_l
    
    for i in range(len(outputs)-1):  
        cv2.line(canvas, (int((i+0.5)*single_candle_w),int(scale_p(outputs[i][1]))), (int((i+1+0.5)*single_candle_w),int(scale_p(outputs[i+1][1]))), (0,200,0))
        cv2.line(canvas, (int((i+0.5)*single_candle_w),int(scale_p(outputs[i][0]))), (int((i+1+0.5)*single_candle_w),int(scale_p(outputs[i+1][0]))), (0,0,200))

    canvas = canvas[::-1]
    
    cv2.imshow("outputs", canvas)
    cv2.waitKey(1)

# %%
pos_size = 0.05 * 100000
comm = 15/100000

tm = timeframe_manager(candles)
current_position = 0
balance = 0
equity = 0
reset_entry_price = False
entry_price = 1

eq_list = []
outputs = deque(maxlen = dlen)
try:
    while True:
        m15,h1,h4,d1 = tm.get_next_sample_candles()
        if m15 == -1:
            break

        if reset_entry_price: entry_price = m15[-1].o
        current_close = m15[-1].c
        percent_change = (current_close - entry_price) / entry_price


        equity = balance + percent_change * pos_size * current_position
        eq_list.append(equity)

        m15i = np.array(tm.to_model_input(m15)).reshape(1,res_high+1,dlen+1)
        h1i = np.array(tm.to_model_input(h1)).reshape(1,res_high+1,dlen+1)
        h4i = np.array(tm.to_model_input(h4)).reshape(1,res_high+1,dlen+1)
        d1i = np.array(tm.to_model_input(d1)).reshape(1,res_high+1,dlen+1)
        output = model([m15i, h1i, h4i, d1i, np.array(current_position).reshape(1,1)]).numpy()

        outputs.append(output[0])

        action = np.argmax(output)
        was_entry = 0
        reset_entry_price = False
        if int(m15[-1].t.split(":")[0]) >= 16 and int(m15[-1].t.split(":")[0]) < 19:
            if current_position != 0:
                was_entry = 2
                current_position = 0
                balance = equity
        else:
            if action == 1: # long
                if current_position != 1:
                    balance = equity
                    current_position = 1
                    balance -= pos_size * comm
                    reset_entry_price = True
                    was_entry = 1
                    #print("long")

            if action == 0: # short
                if current_position != -1:
                    balance = equity
                    current_position = -1
                    balance -= pos_size * comm
                    reset_entry_price = True
                    was_entry = -1
                    #print("short")



        plot_candles(m15,"m15", True, was_entry)
        plot_candles(h1,"h1")
        plot_candles(h4,"h4")
        plot_candles(d1,"d1")
        plot_outputs(outputs)
        print("\r", round(equity,5), " . ", current_position, end = "  ")
        
        
        break
except:
    pass
# Out:
#  0.0  .  0

# %%
inp = [m15i, h1i, h4i, d1i, np.array(current_position).reshape(1,1)]

for i in model.layers[10:]:
    if ("conv" in i.name or "dense" in i.name or "posi" in i.name or "transfo" in i.name or "norm" in i.name):
        m = tf.keras.Model(inputs = model.inputs, outputs = i.output)
        out = m(inp)[0]
        print(i.name, i.output.shape, np.max(out), np.min(out))
        if len(out.shape) == 3:
            c = out.shape[-1]
            h = int(c/8)
            if c%8 !=0:
                h += 1
            fig, ax = plt.subplots(,8, figsize = (20,10))
            for o in range(c):
                im= out[:,:,o]
                ind1 = int(o/8)
                ind2 = o%8
                ax[ind1,ind2].imshow(cv2.resize(im.numpy(), (100,100)))
            plt.show()
        else:
            plt.imshow(out)
            plt.show()
# Out:
#   File "<ipython-input-16-a3732e84a59d>", line 13
#     fig, ax = plt.subplots(,8, figsize = (20,10))
#                            ^
# SyntaxError: invalid syntax
